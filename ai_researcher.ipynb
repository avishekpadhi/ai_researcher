# %% [markdown]
# # Deep Research Agent with Open Models

# %% [markdown]
# ## Setup

# %%
# %pip install -Uq "smolagents[mcp,litellm,openai]" huggingface_hub

# %%
import os
import getpass
os.environ["OPENAI_API_KEY"] = getpass.getpass("OpenAI API Key:")
os.environ["FIRECRAWL_API_KEY"] = getpass.getpass("Firecrawl API Key:")
os.environ["HF_TOKEN"] = getpass.getpass("Hugging Face Token:")
# Out:
# OpenAI API Key:··········
# Firecrawl API Key:··········
# Hugging Face Token:··········

# %% [markdown]
# ## Generate research plan
#
# First, we will have the LLM generate a research plan that will serve as anchor for all our sub agents.

# %%
PLANNER_SYSTEM_INSTRUCTIONS= """
You will be given a research task by a user. Your job is to produce a set of
instructions for a researcher that will complete the task. Do NOT complete the
task yourself, just provide instructions on how to complete it.

GUIDELINES:
1. Maximize specificity and detail. Include all known user preferences and
   explicitly list key attributes or dimensions to consider.
2. If essential attributes are missing, explicitly state that they are open-ended.
3. Avoid unwarranted assumptions. Treat unspecified dimensions as flexible.
4. Use the first person (from the user's perspective).
5. When helpful, explicitly ask the researcher to include tables.
6. Include the expected output format (e.g. structured report with headers).
7. Preserve the input language unless the user explicitly asks otherwise.
8. Sources: prefer primary / official / original sources.
"""


from huggingface_hub import InferenceClient

def generate_research_plan(user_query: str) -> str:
    MODEL_ID = "moonshotai/Kimi-K2-Thinking"
    PROVIDER = "together"

    print("Generating the research plan for the query: ", user_query)
    print("MODEL: ", MODEL_ID)
    print("PROVIDER: ", PROVIDER)

    planner_client = InferenceClient(
        api_key=os.environ["HF_TOKEN"],
        provider=PROVIDER,
        bill_to="huggingface",
    )
    completion = planner_client.chat.completions.create(
        model=MODEL_ID,
        messages=[
            {"role": "system", "content": PLANNER_SYSTEM_INSTRUCTIONS},
            {"role": "user", "content": user_query},
        ],
    )

    research_plan = completion.choices[0].message.content

    print("\033[93mGenerated Research Plan\033[0m")
    print(f"\033[93m{research_plan}\033[0m")

    return research_plan

research_plan = generate_research_plan("research about the climate in northern france")
# Out:
# Generating the research plan for the query:  research about the climate in northern france
# MODEL:  moonshotai/Kimi-K2-Thinking
# PROVIDER:  together
# Generated Research Plan
# I need a comprehensive research report on the climate of northern France. Please follow these detailed instructions:
#
# ---
#
# ### **1. Geographic and Temporal Scope (CLARIFICATION REQUIRED)**
#
# First, confirm the exact geographic boundaries I want to study. Since "northern France" is ambiguous, **explicitly state your interpretation** and provide data for both possible definitions:
# - **Definition A**: Administrative regions (Hauts-de-France, Normandy, Île-de-France, and parts of Brittany)
# - **Definition B**: Geographic threshold (all departments north of the Loire River)
#
# **Time periods to cover** (these are open-ended; gather what's available):
# - **Historical baseline**: 1961-1990 or 1981-2010 climate normals
# - **Recent trends**: 2000-2023 data
# - **Future projections**: Include at least two IPCC scenarios (e.g., SSP2-4.5 and SSP5-8.5) for 2050 and 2100 if accessible
#
# ---
#
# ### **2. Essential Climate Parameters & Data Sources**
#
# For each geographic unit (region or department), **must include**:
# - **Temperature**: Mean annual, seasonal (DJF/MAM/JJA/SON), monthly extremes (record highs/lows), growing degree days, frost days
# - **Precipitation**: Annual totals, seasonal distribution, number of rainy days (>1mm), intensity categories (heavy rainfall events >30mm/day), dry spell duration
# - **Sunshine**: Annual sunshine hours, seasonal variation (critical for agriculture/tourism)
# - **Wind**: Prevailing wind directions, average speeds, storm frequency (Beaufort scale ≥8)
# - **Humidity**: Relative humidity averages, fog days
# - **Extreme events**: Historical flooding, heatwaves, droughts, storms (with dates and impacts)
#
# **Data Source Hierarchy** (strictly follow this order):
# 1. **Primary**: Météo-France official climate data (https://meteofrance.com) - use their "Climatologie" portal
# 2. **Primary**: European Climate Assessment & Dataset (ECA&D) for cross-validated observations
# 3. **Primary**: Copernicus Climate Change Service (C3S) for EU-wide data
# 4. **Secondary**: Peer-reviewed articles from *Climate Research*, *International Journal of Climatology*
# 5. **Tertiary**: NOAA/NCEI only for comparative global context
#
# ---
#
# ### **3. Required Analytical Dimensions**
#
# Structure your analysis around these **seven dimensions**:
#
# **A. Seasonal Patterns**
# - Create a table showing monthly climate normals (temp/precip/sunshine) for 3 representative cities: Lille (inland), Rouen (maritime), and Brest (Atlantic)
# - Identify the "core winter" (months with avg temp <5°C) and "core summer" (months with avg temp >18°C)
#
# **B. Spatial Variation**
# - Map or table comparing: coastal vs. inland climate, urban (Lille metro) vs. rural (Ardennes), altitude effects (if any)
# - Quantify the "north-south gradient" within northern France itself (e.g., Nord vs. Loiret)
#
# **C. Maritime Influence**
# - Analyze the North Atlantic Oscillation (NAO) correlation with winter temperatures
# - Calculate oceanicity index (Duchemin's formula: (P_max - P_min)/T_range)
#
# **D. Climate Change Trends**
# - Linear trends for 1990-2023: temperature increase rate (°C/decade), precipitation change (%/decade)
# - Compare to global average (1.1°C) and French national average
# - Identify "climate signal emergence" year when trends became statistically significant
#
# **E. Microclimates**
# - Document at least 3 distinct microclimates: Flanders plain, Normandy bocage, Paris basin edge
# - Include soil temperature and humidity differences if data available
#
# **F. Sector-Specific Impacts**
# - **Agriculture**: Growing season length (first/last frost dates), water deficit periods
# - **Energy**: Heating degree days (base 18°C), cooling degree days (base 21°C)
# - **Infrastructure**: Freeze-thaw cycles, wind load standards, pluvial flood risk
#
# **G. Uncertainty & Limitations**
# - Explicitly state data gaps, station inhomogeneities, and projection uncertainties
# - Include confidence intervals for all quantitative statements
#
# ---
#
# ### **4. Output Format Requirements**
#
# Deliver a **structured report** with these exact sections:
#
# 1. **Executive Summary** (max 300 words)
# 2. **Geographic & Data Scope** (your interpretation of boundaries and sources used)
# 3. **Current Climate Profile** (main parameters with tables)
# 4. **Spatial and Temporal Variability** (maps/trends)
# 5. **Climate Change Assessment** (observed and projected changes)
# 6. **Sectoral Implications** (agriculture, energy, urban planning)
# 7. **Data Sources & Methodology** (full citations with URLs)
# 8. **Limitations & Gaps** (explicitly stated)
# 9. **Appendices**:
#    - Raw data tables (CSV format recommendation)
#    - List of all Météo-France stations used with coordinates
#
# **Visualization requirements**:
# - Include at least 4 climate diagrams (Walter-Lieth type) for representative locations
# - Include one trend graph showing 30-year moving averages
# - All maps must have scale bars and north arrows
#
# ---
#
# ### **5. Special Instructions**
#
# - **Language**: English (all sources in French must be translated with original text in footnotes)
# - **Units**: Use metric system exclusively; temperatures in Celsius
# - **Citations**: Every quantitative claim must have a superscript citation to a primary source
# - **Currency**: All data must be current as of 2023; if using older data, justify why
# - **Table requirement**: Create a master comparison table (see below) - this is mandatory
#
# **Example table structure you MUST include**:
# | Parameter | Lille (Inland) | Le Havre (Coastal) | Ardennes (Rural/Elevated) | Units |
# |-----------|----------------|-------------------|---------------------------|-------|
# | Avg Annual Temp | | | | °C |
# | Annual Precip | | | | mm |
# | Winter Temp (DJF) | | | | °C |
# | Summer Temp (JJA) | | | | °C |
# | Sunshine Hours/Year | | | | hours |
# | Days with Frost | | | | days/year |
# | Days with Rain >10mm | | | | days/year |
#
# ---
#
# **Before starting**: Send me a brief confirmation of your interpreted geographic scope and the specific Météo-France stations you plan to use, so I can approve the approach.

# %% [markdown]
# ## Split into subtasks
#
# Next, we will split the research plan into multiple research subtasks that will be run by our subagents agents.

# %%
import json
from pydantic import BaseModel, Field
from typing import List
from pprint import pprint

TASK_SPLITTER_SYSTEM_INSTRUCTIONS = """
You will be given a set of research instructions (a research plan).
Your job is to break this plan into a set of coherent, non-overlapping
subtasks that can be researched independently by separate agents.

Requirements:
- 3 to 8 subtasks is usually a good range. Use your judgment.
- Each subtask should have:
  - an 'id' (short string),
  - a 'title' (short descriptive title),
  - a 'description' (clear, detailed instructions for the sub-agent).
- Subtasks should collectively cover the full scope of the original plan
  without unnecessary duplication.
- Prefer grouping by dimensions: time periods, regions, actors, themes,
  causal mechanisms, etc., depending on the topic.
- Each description should be very clear and detailed about everything that
  the agent needs to research to cover that topic.
- Do not include a final task that will put everything together.
  This will be done later in another step.

Output format:
Return ONLY valid JSON with this schema:

{
  "subtasks": [
    {
      "id": "string",
      "title": "string",
      "description": "string"
    }
  ]
}
"""

class Subtask(BaseModel):
    id: str = Field(
        ...,
        description="Short identifier for the subtask (e.g. 'A', 'history', 'drivers').",
    )
    title: str = Field(
        ...,
        description="Short descriptive title of the subtask.",
    )
    description: str = Field(
        ...,
        description="Clear, detailed instructions for the sub-agent that will research this subtask.",
    )

class SubtaskList(BaseModel):
    subtasks: List[Subtask] = Field(
        ...,
        description="List of subtasks that together cover the whole research plan.",
    )

TASK_SPLITTER_JSON_SCHEMA = {
    "name": "subtaskList",
    "schema": SubtaskList.model_json_schema(),
    "strict": True,
}


def split_into_subtasks(research_plan: str):

    MODEL_ID = "moonshotai/Kimi-K2-Thinking"
    PROVIDER = "nebius"

    print("Splitting the research plan into subtasks...")
    print("MODEL: ", MODEL_ID)
    print("PROVIDER: ", PROVIDER)

    client = InferenceClient(
      api_key=os.environ["HF_TOKEN"],
      provider=PROVIDER,
      bill_to="huggingface",
    )

    completion = client.chat_completion(
        model=MODEL_ID,
        messages=[
            {"role": "system", "content": TASK_SPLITTER_SYSTEM_INSTRUCTIONS},
            {"role": "user", "content": research_plan},
        ],
        response_format={
            "type": "json_schema",
            "json_schema": TASK_SPLITTER_JSON_SCHEMA,
        },
    )

    message = completion.choices[0].message

    print(message)

    subtasks = json.loads(message.content)['subtasks']

    print("\033[93mGenerated The Following Subtasks\033[0m")
    for task in subtasks:
      print(f"\033[93m{task['title']}\033[0m")
      pprint(f"\033[93m{task['description']}\033[0m")
      print()

    return subtasks

subtasks = split_into_subtasks(research_plan)
# Out:
# Splitting the research plan into subtasks...
# MODEL:  moonshotai/Kimi-K2-Thinking
# PROVIDER:  nebius
# ChatCompletionOutputMessage(role='assistant', content=' {"subtasks":[{"id":"geographic_baseline","title":"Geographic Scope Definition and Baseline Climate Normals (1991-2020)","description":"Define \'northern France\' as the administrative regions of Hauts-de-France and Normandy, plus the northern portions of Grand Est and Brittany. Establish five representative reference cities: Lille (inland urban), Calais (coastal Channel), Rouen (Seine valley), Le Havre (coastal Atlantic), and Amiens (inland plain). For each location, gather comprehensive climate normals for the 1991-2020 WMO standard period from Météo-France Climate Atlas and ECMWF ERA5 reanalysis. Collect all core variables: mean monthly/annual temperatures and daily highs/lows; absolute temperature records with dates; frost day counts; growing season length; sea surface temperatures for coastal cities; monthly/annual precipitation totals and precipitation days (≥1mm); seasonal precipitation distribution; snowfall frequency and accumulation; heavy rainfall events (>30mm/24h); consecutive dry days statistics; monthly sunshine hours and percentage of possible sunshine; cloud cover percentages; UV index patterns; seasonal prevailing wind directions and average speeds; gale-force event frequency (>62 km/h); storm track influences; mean monthly relative humidity; atmospheric pressure patterns; and fog frequency. Document exact dataset versions and URLs for all sources. Create preliminary summary statistics for each city and variable to support later tabulation."},{"id":"historical_trends","title":"Historical Climate Change Analysis and Trend Quantification","description":"Compile climate data for the 1961-1990 reference period to enable comparison with 1991-2020 normals. Quantify observed warming trends in °C per decade from the 1970s through 2023 using linear regression on annual mean temperatures from Météo-France station data and peer-reviewed studies. Calculate percentage changes in annual and seasonal precipitation between the two reference periods. Document shifts in extreme weather event frequency: increases/decreases in heavy rainfall days, gale-force winds, heatwaves, and drought periods. Assess sea-level rise trends for coastal reference cities using data from the Permanent Service for Mean Sea Level (PSMSL) and French coastal observatories. Identify emerging climate anomalies specific to northern France (e.g., delayed autumn frosts, altered storm tracks). Search academic databases (Scopus, Web of Science) for peer-reviewed articles on climate change in northern France, Normandy, and Hauts-de-France, prioritizing studies published since 2015. Extract quantitative findings on phenological shifts, agricultural impacts, and hydrological changes. Synthesize evidence for attribution of observed changes to anthropogenic forcing versus natural variability."},{"id":"future_projections","title":"Future Climate Projections and Scenario Modeling (2050, 2100)","description":"Extract IPCC CMIP6 multi-model ensemble data for the northern France domain from the official IPCC data portal. Focus on two Shared Socioeconomic Pathways: SSP2-4.5 (medium emissions) and SSP5-8.5 (high emissions). Derive projected changes for 2050 (2041-2060) and 2100 (2081-2100) relative to the 1991-2020 baseline for all core climate variables: temperature (mean, seasonal, extreme highs/lows), precipitation (annual totals, seasonal redistribution, heavy rainfall intensity), sunshine/cloud cover, wind patterns, and humidity. Include uncertainty ranges (10th-90th percentile) from model ensembles. Reference the IPCC AR6 WGI report Chapter 12 (Central and Western Europe) for regional climate projection context. Identify robust signals across models versus uncertain projections. Analyze projected changes in frost days, growing season length, and heatwave frequency. Assess potential shifts in storm tracks affecting Channel and Atlantic coasts. Document any projected changes in sea surface temperatures that coul ...
# Generated The Following Subtasks
# Geographic Scope Definition and Baseline Climate Normals (1991-2020)
# ("\x1bDefine 'northern France' as the administrative regions of "
#  'Hauts-de-France and Normandy, plus the northern portions of Grand Est and '
#  'Brittany. Establish five representative reference cities: Lille (inland '
#  'urban), Calais (coastal Channel), Rouen (Seine valley), Le Havre (coastal '
#  'Atlantic), and Amiens (inland plain). For each location, gather '
#  'comprehensive climate normals for the 1991-2020 WMO standard period from '
#  'Météo-France Climate Atlas and ECMWF ERA5 reanalysis. Collect all core '
#  'variables: mean monthly/annual temperatures and daily highs/lows; absolute '
#  'temperature records with dates; frost day counts; growing season length; sea '
#  'surface temperatures for coastal cities; monthly/annual precipitation totals '
#  'and precipitation days (≥1mm); seasonal precipitation distribution; snowfall '
#  'frequency and accumulation; heavy rainfall events (>30mm/24h); consecutive '
#  'dry days statistics; monthly sunshine hours and percentage of possible '
#  'sunshine; cloud cover percentages; UV index patterns; seasonal prevailing '
#  'wind directions and average speeds; gale-force event frequency (>62 km/h); '
#  'storm track influences; mean monthly relative humidity; atmospheric pressure '
#  'patterns; and fog frequency. Document exact dataset versions and URLs for '
#  'all sources. Create preliminary summary statistics for each city and '
#  'variable to support later tabulation.\x1b')
#
# Historical Climate Change Analysis and Trend Quantification
# ('\x1bCompile climate data for the 1961-1990 reference period to enable '
#  'comparison with 1991-2020 normals. Quantify observed warming trends in °C '
#  'per decade from the 1970s through 2023 using linear regression on annual '
#  'mean temperatures from Météo-France station data and peer-reviewed studies. '
#  'Calculate percentage changes in annual and seasonal precipitation between '
#  'the two reference periods. Document shifts in extreme weather event '
#  'frequency: increases/decreases in heavy rainfall days, gale-force winds, '
#  'heatwaves, and drought periods. Assess sea-level rise trends for coastal '
#  'reference cities using data from the Permanent Service for Mean Sea Level '
#  '(PSMSL) and French coastal observatories. Identify emerging climate '
#  'anomalies specific to northern France (e.g., delayed autumn frosts, altered '
#  'storm tracks). Search academic databases (Scopus, Web of Science) for '
#  'peer-reviewed articles on climate change in northern France, Normandy, and '
#  'Hauts-de-France, prioritizing studies published since 2015. Extract '
#  'quantitative findings on phenological shifts, agricultural impacts, and '
#  'hydrological changes. Synthesize evidence for attribution of observed '
#  'changes to anthropogenic forcing versus natural variability.\x1b')
#
# Future Climate Projections and Scenario Modeling (2050, 2100)
# ('\x1bExtract IPCC CMIP6 multi-model ensemble data for the northern France '
#  'domain from the official IPCC data portal. Focus on two Shared Socioeconomic '
#  'Pathways: SSP2-4.5 (medium emissions) and SSP5-8.5 (high emissions). Derive '
#  'projected changes for 2050 (2041-2060) and 2100 (2081-2100) relative to the '
#  '1991-2020 baseline for all core climate variables: temperature (mean, '
#  'seasonal, extreme highs/lows), precipitation (annual totals, seasonal '
#  'redistribution, heavy rainfall intensity), sunshine/cloud cover, wind '
#  'patterns, and humidity. Include uncertainty ranges (10th-90th percentile) '
#  'from model ensembles. Reference the IPCC AR6 WGI report Chapter 12 (Central '
#  'and Western Europe) for regional climate projection context. Identify robust '
#  'signals across models versus uncertain projections. Analyze projected '
#  'changes in frost days, growing season length, and heatwave frequency. Assess '
#  'potential shifts in storm tracks affecting Channel and Atlantic coasts. '
#  'Document any projected changes in sea surface temperatures that could '
#  'influence coastal climates. Note spatial variations in projected changes '
#  'across the defined sub-regions.\x1b')
#
# Regional Comparison and Köppen-Geiger Climate Classification
# ('\x1bDefine and compare at least four distinct sub-regions within '
#  'northern France: (1) Inland Plain of Flanders (Lille area), (2) Channel '
#  'Coast (Calais to Dieppe), (3) Normandy Bocage (Rouen interior), and (4) '
#  'Ardennes Foothills (southern edge of Grand Est). For each sub-region, '
#  'determine the precise Köppen-Geiger climate classification using the most '
#  'recent global classification maps (e.g., Beck et al., 2018) and local data. '
#  'Analyze microclimate effects: quantify urban heat island intensity for Lille '
#  'using Météo-France urban/rural station pairs; assess coastal moderation '
#  'effects on temperature ranges and frost frequency for Le Havre and Calais; '
#  'identify orographic precipitation enhancement in the Ardennes foothills. '
#  'Create comparison tables showing mean annual temperature, temperature range, '
#  'annual precipitation, precipitation seasonality, and sunshine hours for each '
#  'sub-region. Document any local climate gradients (e.g., east-west '
#  'precipitation gradient, north-south temperature gradient). Search for '
#  'site-specific climate studies in each sub-region, particularly from French '
#  'academic institutions (Université de Lille, Université de Rouen '
#  'Normandie).\x1b')

# %% [markdown]
# ## Create subagents + coordinator
#
# In this step, we’ll create a tool that spins up a dedicated sub-agent for each subtask. This tool will be handed to the Coordinator agent, which will invoke it whenever a new subtask needs to be processed. Each sub-agent will perform thorough research on its assigned subtask and return its findings once completed. The Coordinator will then aggregate all sub-agent outputs into a comprehensive deep-research report.

# %%
SUBAGENT_PROMPT_TEMPLATE = """
You are a specialized research sub-agent.

Global user query:
{user_query}

Overall research plan:
{research_plan}

Your specific subtask (ID: {subtask_id}, Title: {subtask_title}) is:

\"\"\"{subtask_description}\"\"\"

Instructions:
- Focus ONLY on this subtask, but keep the global query in mind for context.
- Use the available tools to search for up-to-date, high-quality sources.
- Prioritize primary and official sources when possible.
- Be explicit about uncertainties, disagreements in the literature, and gaps.
- Return your results as a MARKDOWN report with this structure:

# [Subtask ID] [Subtask Title]

## Summary
Short overview of the main findings.

## Detailed Analysis
Well-structured explanation with subsections as needed.

## Key Points
- Bullet point
- Bullet point

## Sources
- [Title](url) - short comment on why this source is relevant

Now perform the research and return ONLY the markdown report.
"""

COORDINATOR_PROMPT_TEMPLATE = """
You are the LEAD RESEARCH COORDINATOR AGENT.

The user has asked:
\"\"\"{user_query}\"\"\"

A detailed research plan has already been created:

\"\"\"{research_plan}\"\"\"

This plan has been split into the following subtasks (JSON):

```json
{subtasks_json}
```
Each element has the shape:
{{
“id”: “timeframe_confirmation”,
“title”: “Confirm Research Scope Parameters”,
“description”: “Analyze the scope parameters…”
}}

You have access to a tool called:
• initialize_subagent(subtask_id: str, subtask_title: str, subtask_description: str)

Your job:
1. For EACH subtask in the JSON array, call initialize_subagent exactly once
with:
• subtask_id       = subtask[“id”]
• subtask_title    = subtask[“title”]
• subtask_description = subtask[“description”]
2. Wait for all sub-agent reports to come back. Each tool call returns a
markdown report for that subtask.
3. After you have results for ALL subtasks, synthesize them into a SINGLE,
coherent, deeply researched report addressing the original user query
("{user_query}").

Final report requirements:
• Integrate all sub-agent findings; avoid redundancy.
• Make the structure clear with headings and subheadings.
• Highlight:
• key drivers and mechanisms of insecurity,
• historical and temporal evolution,
• geographic and thematic patterns,
• state capacity, public perception, and socioeconomic correlates,
• open questions and uncertainties.
• Include final sections:
• Open Questions and Further Research
• Bibliography / Sources: merge and deduplicate the key sources from all sub-agents.

Important:
• DO NOT expose internal tool-call mechanics to the user.
• Your final answer to the user should be a polished markdown report.
"""

# %%
from smolagents import InferenceClientModel, MCPClient, tool, ToolCallingAgent
import os

FIRECRAWL_API_KEY = os.environ["FIRECRAWL_API_KEY"]
MCP_URL = f"https://mcp.firecrawl.dev/{FIRECRAWL_API_KEY}/v2/mcp"

COORDINATOR_MODEL_ID = "MiniMaxAI/MiniMax-M1-80k"
SUBAGENT_MODEL_ID = "MiniMaxAI/MiniMax-M1-80k"
COORDINATOR_MODEL_PROVIDER = "novita"
SUBAGENT_MODEL_PROVIDER = "novita"

def run_deep_research(user_query: str) -> str:
    print("Running the deep research...")

    # 1) Generate research plan
    research_plan = generate_research_plan(user_query)

    # 2) Split into explicit subtasks
    subtasks = split_into_subtasks(research_plan)

    print("Initializing Coordinator")
    print("Coordinator Model: ", COORDINATOR_MODEL_ID)
    print("Subagent Model: ", SUBAGENT_MODEL_ID)

    coordinator_model = InferenceClientModel(
        model_id=COORDINATOR_MODEL_ID,
        api_key=os.environ["HF_TOKEN"],
        provider=COORDINATOR_MODEL_PROVIDER,
        bill_to="huggingface"
        )
    subagent_model = InferenceClientModel(
        model_id=SUBAGENT_MODEL_ID,
        api_key=os.environ["HF_TOKEN"],
        provider=SUBAGENT_MODEL_PROVIDER,
        bill_to="huggingface"
        )

    with MCPClient({"url": MCP_URL, "transport": "streamable-http"}) as mcp_tools:
        @tool
        def initialize_subagent(subtask_id: str, subtask_title: str, subtask_description: str) -> str:
            """
           Spawn a dedicated research sub-agent for a single subtask.

            Args:
                subtask_id (str): The unique identifier for the subtask.
                subtask_title (str): The descriptive title of the subtask.
                subtask_description (str): Detailed instructions for the sub-agent to perform the subtask.

            The sub-agent:
            - Has access to the Firecrawl MCP tools.
            - Must perform deep research ONLY on this subtask.
            - Returns a structured markdown report with:
              - a clear heading identifying the subtask,
              - a narrative explanation,
              - bullet-point key findings,
              - explicit citations / links to sources.
            """
            print(f"Initializing Subagent for task {subtask_id}...")

            subagent = ToolCallingAgent(
                tools=mcp_tools,                # Firecrawl MCP toolkit
                model=subagent_model,
                add_base_tools=False,
                name=f"subagent_{subtask_id}",
            )
            subagent_prompt = SUBAGENT_PROMPT_TEMPLATE.format(
                user_query=user_query,
                research_plan=research_plan,
                subtask_id=subtask_id,
                subtask_title=subtask_title,
                subtask_description=subtask_description,
            )

            return subagent.run(subagent_prompt)

        coordinator = ToolCallingAgent(
            tools=[initialize_subagent],
            model=coordinator_model,
            add_base_tools=False,
            name="coordinator_agent"
        )

        subtasks_json = json.dumps(subtasks, indent=2, ensure_ascii=False)

        coordinator_prompt = COORDINATOR_PROMPT_TEMPLATE.format(
            user_query=user_query,
            research_plan=research_plan,
            subtasks_json=subtasks_json,
        )

        final_report = coordinator.run(coordinator_prompt)

        return final_report

# %% [markdown]
# ## Final result
#
# This is the result of running the entire Deep Research Pipeline

# %%
result = run_deep_research("research the climate in northern france")
# Out:
# Running the deep research...
# Generating the research plan for the query:  research the climate in northern france
# MODEL:  moonshotai/Kimi-K2-Thinking
# PROVIDER:  together
# Generated Research Plan
# **Research Brief: Climate in Northern France**
#
# I need a comprehensive research report on the climate characteristics of northern France. Since some parameters are undefined, please either confirm these choices with me or proceed using the standard recommendations below and explicitly state your assumptions in the report.
#
# ---
#
# ### **1. GEOGRAPHIC SCOPE (To Be Defined)**
# Clarify the spatial boundaries before proceeding:
# - **Preferred Definition**: Use administrative regions of Hauts-de-France, Normandy, and the northern portions of Grand Est (Ardennes, Meuse, Meurthe-et-Moselle) and Île-de-France.
# - **Key Distinction**: Separate analysis for:
#   - Coastal zones (Channel/North Sea: from Dunkirk to Le Havre)
#   - Inland areas (Artois, Flanders, Picardy plateaus)
#   - Urban heat island effects (Lille, Rouen, Strasbourg, Paris comparative data)
# - If I don't respond, **proceed with the four-region definition above** and create sub-sections for coastal vs. inland climates.
#
# ---
#
# ### **2. TIME PERIOD COVERAGE (To Be Defined)**
# Specify the temporal focus:
# - **Historical Baseline**: 1991-2020 climatological normals (WMO standard)
# - **Recent Trends**: 2000-2023 for change detection
# - **Climate Projections**: Include only if specifically relevant to current planning (2050 horizon, RCP4.5/RCP8.5 scenarios)
# - If I don't respond, **focus on 1991-2020 normals with trend analysis from 2000-2023** and exclude future projections.
#
# ---
#
# ### **3. ESSENTIAL CLIMATE VARIABLES TO RESEARCH**
# For each variable, include:
# - **Temperature**: Monthly/seasonal means, absolute records, diurnal range, frost days, growing degree days
# - **Precipitation**: Monthly/seasonal totals, number of rainy days (>1mm), intensity percentiles, snow frequency, hail occurrence
# - **Atmospheric Moisture**: Relative humidity, dew point, fog days
# - **Wind**: Prevailing direction, average speed, storm/gale days
# - **Sunshine**: Monthly sunshine hours, cloud cover percentage
# - **Pressure Systems**: Dominant patterns (North Atlantic Oscillation influence)
# - **Extreme Events**: Return periods for 24h precipitation >50mm, heatwaves (>30°C), cold snaps (<-5°C)
#
# ---
#
# ### **4. REQUIRED DATA SOURCES (Prioritized)**
# 1. **Primary**: Météo-France official climatological data ([https://donneespubliques.meteofrance.fr](https://donneespubliques.meteofrance.fr))
# 2. **European**: E-OBS gridded dataset (ECA&D project) for spatial analysis
# 3. **Academic**: Recent peer-reviewed studies from *La Météorologie* journal and CNRS climate research units
# 4. **Historical**: IPCC AR6 report for broader context
# 5. **Avoid**: Travel blogs, non-scientific websites, or unverified sources
#
# ---
#
# ### **5. ANALYTICAL DIMENSIONS TO COVER**
# - **Maritime vs. Continental Gradient**: Quantify the transition from coastal to inland climate
# - **Seasonal Patterns**: Deep dive into winter maritime moderation vs. summer convective rainfall
# - **Topographic Effects**: Ardennes, Normandy hills influence on precipitation
# - **North Atlantic Oscillation (NAO)**: Correlation with winter temperature/precipitation anomalies
# - **Urban-Rural Contrasts**: Lille and Paris heat islands vs. surrounding countryside
# - **Climate Change Signals**: Trend significance testing for temperature/precipitation 1950-2023
#
# ---
#
# ### **6. MANDATORY VISUALIZATIONS & TABLES**
# Include exactly these tables:
# - **Table 1**: Seasonal climate metrics (temperature, precipitation, sunshine) for 5 representative stations (Dunkirk, Lille, Rouen, Strasbourg, Metz)
# - **Table 2**: Comparison of northern France
# Splitting the research plan into subtasks...
# MODEL:  moonshotai/Kimi-K2-Thinking
# PROVIDER:  nebius
# ChatCompletionOutputMessage(role='assistant', content=' {"subtasks":[{"id":"geo-framework","title":"Geographic Scope and Spatial Framework Definition","description":"Define the exact spatial boundaries of the study area per the research brief: Hauts-de-France, Normandy, northern Grand Est (Ardennes, Meuse, Meurthe-et-Moselle), and Île-de-France. Identify and map three distinct zones: (1) Coastal zones along the Channel/North Sea from Dunkirk to Le Havre, (2) Inland areas including Artois, Flanders, and Picardy plateaus, (3) Urban agglomerations for heat island analysis (Lille, Rouen, Strasbourg, Paris). Select the five mandatory representative stations (Dunkirk, Lille, Rouen, Strasbourg, Metz) plus at least 10 additional stations to ensure adequate spatial coverage. Document the latitude, longitude, elevation, and data availability period for each station. Create a base map showing administrative boundaries, zones, and station locations. Quantify the maritime-continental gradient distance from coast to furthest inland point. This framework will enable consistent spatial analysis across all climate variables. Use Météo-France station metadata and geographic information systems. State explicitly that the four-region definition is being used per the standard recommendation since no alternative was specified."},{"id":"temperature-regime","title":"Temperature Regime and Urban Heat Island Analysis","description":"Research all temperature-related variables across the defined geographic scope. Extract monthly and seasonal mean temperatures, absolute maximum and minimum records, diurnal temperature range, number of frost days (Tmin < 0°C), and growing degree days (base 10°C) for the period 1991-2020. For urban heat island analysis, obtain comparative temperature data for urban stations (Lille, Rouen, Strasbourg, Paris) and at least two rural stations per city at similar elevation within 50km radius. Calculate mean annual and seasonal UHI intensity. Use Météo-France official climatological data as primary source, supplemented by E-OBS gridded data for spatial interpolation of temperature fields. Analyze 2000-2023 trends for all metrics, comparing against 1991-2020 normals. Include analysis of temperature variability and persistence of extreme warm/cold spells. Document data quality control procedures applied."},{"id":"precipitation-moisture","title":"Precipitation, Snow, and Atmospheric Moisture Characteristics","description":"Research precipitation and moisture variables for the entire study area. Extract monthly and seasonal precipitation totals, number of rainy days (>1mm threshold), precipitation intensity percentiles (90th, 95th, 99th), snow frequency and average snow depth days, and hail occurrence from Météo-France stations. Research atmospheric moisture variables: mean relative humidity at 9h and 15h, dew point temperatures, and number of fog days. Analyze topographic effects by comparing precipitation patterns between windward/leeward slopes of Ardennes and Normandy hills using E-OBS high-resolution gridded data. Quantify orographic enhancement ratios. Calculate 2000-2023 trends for all variables and compare with 1991-2020 baseline. Identify any shifts in precipitation seasonality or intensity distribution. Use Météo-France primary data, E-OBS for spatial patterns, and CNRS studies on topographic effects."},{"id":"wind-sunshine-circulation","title":"Wind, Sunshine, and Synoptic Atmospheric Patterns","description":"Research wind characteristics including prevailing direction by season, average wind speed, and number of storm/gale days (Beaufort ≥8) from Météo-France anemometer records. Extract monthly sunshine hours and cloud cover percentage (oktas). Analyze synoptic-scale patterns: document dominant pressure systems by season, research North Atlantic Oscillation (NAO) indices and correlate with winter temperature and precipitation anomalies across the region. Use NAO data from NOAA Climate Prediction Center. Calculate correlat ...
# Generated The Following Subtasks
# Geographic Scope and Spatial Framework Definition
# ('\x1bDefine the exact spatial boundaries of the study area per the '
#  'research brief: Hauts-de-France, Normandy, northern Grand Est (Ardennes, '
#  'Meuse, Meurthe-et-Moselle), and Île-de-France. Identify and map three '
#  'distinct zones: (1) Coastal zones along the Channel/North Sea from Dunkirk '
#  'to Le Havre, (2) Inland areas including Artois, Flanders, and Picardy '
#  'plateaus, (3) Urban agglomerations for heat island analysis (Lille, Rouen, '
#  'Strasbourg, Paris). Select the five mandatory representative stations '
#  '(Dunkirk, Lille, Rouen, Strasbourg, Metz) plus at least 10 additional '
#  'stations to ensure adequate spatial coverage. Document the latitude, '
#  'longitude, elevation, and data availability period for each station. Create '
#  'a base map showing administrative boundaries, zones, and station locations. '
#  'Quantify the maritime-continental gradient distance from coast to furthest '
#  'inland point. This framework will enable consistent spatial analysis across '
#  'all climate variables. Use Météo-France station metadata and geographic '
#  'information systems. State explicitly that the four-region definition is '
#  'being used per the standard recommendation since no alternative was '
#  'specified.\x1b')
#
# Temperature Regime and Urban Heat Island Analysis
# ('\x1bResearch all temperature-related variables across the defined '
#  'geographic scope. Extract monthly and seasonal mean temperatures, absolute '
#  'maximum and minimum records, diurnal temperature range, number of frost days '
#  '(Tmin < 0°C), and growing degree days (base 10°C) for the period 1991-2020. '
#  'For urban heat island analysis, obtain comparative temperature data for '
#  'urban stations (Lille, Rouen, Strasbourg, Paris) and at least two rural '
#  'stations per city at similar elevation within 50km radius. Calculate mean '
#  'annual and seasonal UHI intensity. Use Météo-France official climatological '
#  'data as primary source, supplemented by E-OBS gridded data for spatial '
#  'interpolation of temperature fields. Analyze 2000-2023 trends for all '
#  'metrics, comparing against 1991-2020 normals. Include analysis of '
#  'temperature variability and persistence of extreme warm/cold spells. '
#  'Document data quality control procedures applied.\x1b')
#
# Precipitation, Snow, and Atmospheric Moisture Characteristics
# ('\x1bResearch precipitation and moisture variables for the entire study '
#  'area. Extract monthly and seasonal precipitation totals, number of rainy '
#  'days (>1mm threshold), precipitation intensity percentiles (90th, 95th, '
#  '99th), snow frequency and average snow depth days, and hail occurrence from '
#  'Météo-France stations. Research atmospheric moisture variables: mean '
#  'relative humidity at 9h and 15h, dew point temperatures, and number of fog '
#  'days. Analyze topographic effects by comparing precipitation patterns '
#  'between windward/leeward slopes of Ardennes and Normandy hills using E-OBS '
#  'high-resolution gridded data. Quantify orographic enhancement ratios. '
#  'Calculate 2000-2023 trends for all variables and compare with 1991-2020 '
#  'baseline. Identify any shifts in precipitation seasonality or intensity '
#  'distribution. Use Météo-France primary data, E-OBS for spatial patterns, and '
#  'CNRS studies on topographic effects.\x1b')
#
# Wind, Sunshine, and Synoptic Atmospheric Patterns
# ('\x1bResearch wind characteristics including prevailing direction by '
#  'season, average wind speed, and number of storm/gale days (Beaufort ≥8) from '
#  'Météo-France anemometer records. Extract monthly sunshine hours and cloud '
#  'cover percentage (oktas). Analyze synoptic-scale patterns: document dominant '
#  'pressure systems by season, research North Atlantic Oscillation (NAO) '
#  'indices and correlate with winter temperature and precipitation anomalies '
#  'across the region. Use NAO data from NOAA Climate Prediction Center. '
#  'Calculate correlations at p<0.05 significance level. Research trends in wind '
#  'speed, storm frequency, and sunshine duration between 2000-2023 and '
#  '1991-2020 baseline. Use E-OBS for spatial consistency checks and academic '
#  'literature from *La Météorologie* for process understanding.\x1b')
#
# Extreme Weather Events and Return Period Analysis
# ('\x1bConduct statistical analysis of extreme weather events. Calculate '
#  'return periods for 24-hour precipitation events exceeding 50mm using extreme '
#  'value theory (Generalized Extreme Value distribution) with at least 30 years '
#  'of data. Research heatwave definitions and frequency: events with maximum '
#  'temperature >30°C for at least 3 consecutive days. Research cold snaps: '
#  'events with minimum temperature <-5°C. Document the most significant events '
#  'in 2000-2023 period. Analyze storm tracks and intensity for gale events. Use '
#  'Météo-France high-resolution daily data, apply peaks-over-threshold methods '
#  'where appropriate. Calculate trends in extreme event frequency and '
#  'intensity. Compare with IPCC AR6 conclusions for Western Europe. Ensure '
#  'statistical robustness with confidence intervals for all return period '
#  'estimates.\x1b')
#
# Maritime-Continental Gradient and Seasonal Climate Patterns
# ('\x1bQuantify the maritime to continental climate transition across the '
#  'study area. Calculate coastal (Dunkirk, Le Havre) to inland (Metz, '
#  'Strasbourg) gradients for temperature range, precipitation seasonality, and '
#  'wind exposure for each season. Characterize winter maritime moderation '
#  'effects (reduced frost, higher humidity) versus summer convective rainfall '
#  'patterns. Use E-OBS gridded dataset to create continuous spatial maps of key '
#  'climate indices (e.g., continentality index, oceanity index). Analyze '
#  'seasonal cycles: document timing of maximum/minimum temperature and '
#  'precipitation, length of thermal seasons. Research topographic effects: '
#  'quantify precipitation enhancement on Ardennes windward slopes and rain '
#  'shadow effects. Cross-reference with peer-reviewed studies on regional '
#  'climate dynamics. Provide seasonal climatological summaries for each '
#  'sub-region (coastal, inland plateau, urban).\x1b')
#
# Climate Change Signal Detection and Trend Analysis
# ('\x1bPerform comprehensive trend analysis to detect climate change '
#  'signals. Compare 1991-2020 climatological normals with 2000-2023 data for '
#  'all essential variables, applying Mann-Kendall trend tests and calculating '
#  "Sen's slope estimates with significance levels. Extend temperature and "
#  'precipitation trend analysis back to 1950 where data quality permits using '
#  'Météo-France long-term stations. Assess changes in climate variability '
#  '(interannual standard deviation) and extremes distribution. Quantify shifts '
#  'in phenological indicators such as growing season length and frost-free '
#  'period. Research consistency with IPCC AR6 Western Europe projections and '
#  'recent CNRS climate studies. Separate forced trends from natural variability '
#  '(NAO influence). Document any acceleration of trends in recent decades. For '
#  'urban areas, separate UHI trends from background climate change. Use only '
#  'verified, peer-reviewed methods and state all assumptions explicitly.\x1b')
#
# Initializing Coordinator
# Coordinator Model:  MiniMaxAI/MiniMax-M1-80k
# Subagent Model:  MiniMaxAI/MiniMax-M1-80k
# /tmp/ipython-input-1829780787.py:38: FutureWarning: Parameter 'structured_output' was not specified. Currently it defaults to False, but in version 1.25, the default will change to True. To suppress this warning, explicitly set structured_output=True (new behavior) or structured_output=False (legacy behavior). See documentation at https://huggingface.co/docs/smolagents/tutorials/tools#structured-output-and-output-schema-support for more details.
#   with MCPClient({"url": MCP_URL, "transport": "streamable-http"}) as mcp_tools:
# ╭────────────────────────────────────────── New run - coordinator_agent ──────────────────────────────────────────╮
# │                                                                                                                 │
# │ You are the LEAD RESEARCH COORDINATOR AGENT.                                                                    │
# │                                                                                                                 │
# │ The user has asked:                                                                                             │
# │ """research the climate in northern france"""                                                                   │
# │                                                                                                                 │
# │ A detailed research plan has already been created:                                                              │
# │                                                                                                                 │
# │ """**Research Brief: Climate in Northern France**                                                               │
# │                                                                                                                 │
# │ I need a comprehensive research report on the climate characteristics of northern France. Since some parameters │
# │ are undefined, please either confirm these choices with me or proceed using the standard recommendations below  │
# │ and explicitly state your assumptions in the report.                                                            │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ### **1. GEOGRAPHIC SCOPE (To Be Defined)**                                                                     │
# │ Clarify the spatial boundaries before proceeding:                                                               │
# │ - **Preferred Definition**: Use administrative regions of Hauts-de-France, Normandy, and the northern portions  │
# │ of Grand Est (Ardennes, Meuse, Meurthe-et-Moselle) and Île-de-France.                                           │
# │ - **Key Distinction**: Separate analysis for:                                                                   │
# │   - Coastal zones (Channel/North Sea: from Dunkirk to Le Havre)                                                 │
# │   - Inland areas (Artois, Flanders, Picardy plateaus)                                                           │
# │   - Urban heat island effects (Lille, Rouen, Strasbourg, Paris comparative data)                                │
# │ - If I don't respond, **proceed with the four-region definition above** and create sub-sections for coastal vs. │
# │ inland climates.                                                                                                │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ### **2. TIME PERIOD COVERAGE (To Be Defined)**                                                                 │
# │ Specify the temporal focus:                                                                                     │
# │ - **Historical Baseline**: 1991-2020 climatological normals (WMO standard)                                      │
# │ - **Recent Trends**: 2000-2023 for change detection                                                             │
# │ - **Climate Projections**: Include only if specifically relevant to current planning (2050 horizon,             │
# │ RCP4.5/RCP8.5 scenarios)                                                                                        │
# │ - If I don't respond, **focus on 1991-2020 normals with trend analysis from 2000-2023** and exclude future      │
# │ projections.                                                                                                    │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ### **3. ESSENTIAL CLIMATE VARIABLES TO RESEARCH**                                                              │
# │ For each variable, include:                                                                                     │
# │ - **Temperature**: Monthly/seasonal means, absolute records, diurnal range, frost days, growing degree days     │
# │ - **Precipitation**: Monthly/seasonal totals, number of rainy days (>1mm), intensity percentiles, snow          │
# │ frequency, hail occurrence                                                                                      │
# │ - **Atmospheric Moisture**: Relative humidity, dew point, fog days                                              │
# │ - **Wind**: Prevailing direction, average speed, storm/gale days                                                │
# │ - **Sunshine**: Monthly sunshine hours, cloud cover percentage                                                  │
# │ - **Pressure Systems**: Dominant patterns (North Atlantic Oscillation influence)                                │
# │ - **Extreme Events**: Return periods for 24h precipitation >50mm, heatwaves (>30°C), cold snaps (<-5°C)         │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ### **4. REQUIRED DATA SOURCES (Prioritized)**                                                                  │
# │ 1. **Primary**: Météo-France official climatological data                                                       │
# │ ([https://donneespubliques.meteofrance.fr\](https://donneespubliques.meteofrance.fr))                           │
# │ 2. **European**: E-OBS gridded dataset (ECA&D project) for spatial analysis                                     │
# │ 3. **Academic**: Recent peer-reviewed studies from *La Météorologie* journal and CNRS climate research units    │
# │ 4. **Historical**: IPCC AR6 report for broader context                                                          │
# │ 5. **Avoid**: Travel blogs, non-scientific websites, or unverified sources                                      │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ### **5. ANALYTICAL DIMENSIONS TO COVER**                                                                       │
# │ - **Maritime vs. Continental Gradient**: Quantify the transition from coastal to inland climate                 │
# │ - **Seasonal Patterns**: Deep dive into winter maritime moderation vs. summer convective rainfall               │
# │ - **Topographic Effects**: Ardennes, Normandy hills influence on precipitation                                  │
# │ - **North Atlantic Oscillation (NAO)**: Correlation with winter temperature/precipitation anomalies             │
# │ - **Urban-Rural Contrasts**: Lille and Paris heat islands vs. surrounding countryside                           │
# │ - **Climate Change Signals**: Trend significance testing for temperature/precipitation 1950-2023                │
# │                                                                                                                 │
# │ ---                                                                                                             │
# │                                                                                                                 │
# │ ### **6. MANDATORY VISUALIZATIONS & TABLES**                                                                    │
# │ Include exactly these tables:                                                                                   │
# │ - **Table 1**: Seasonal climate metrics (temperature, precipitation, sunshine) for 5 representative stations    │
# │ (Dunkirk, Lille, Rouen, Strasbourg, Metz)                                                                       │
# │ - **Table 2**: Comparison of northern France"""                                                                 │
# │                                                                                                                 │
# │ This plan has been split into the following subtasks (JSON):                                                    │
# │                                                                                                                 │
# │ ```json                                                                                                         │
# │ [                                                                                                               │
# │   {                                                                                                             │
# │     "id": "geo-framework",                                                                                      │
# │     "title": "Geographic Scope and Spatial Framework Definition",                                               │
# │     "description": "Define the exact spatial boundaries of the study area per the research brief:               │
# │ Hauts-de-France, Normandy, northern Grand Est (Ardennes, Meuse, Meurthe-et-Moselle), and Île-de-France.         │
# │ Identify and map three distinct zones: (1) Coastal zones along the Channel/North Sea from Dunkirk to Le Havre,  │
# │ (2) Inland areas including Artois, Flanders, and Picardy plateaus, (3) Urban agglomerations for heat island     │
# │ analysis (Lille, Rouen, Strasbourg, Paris). Select the five mandatory representative stations (Dunkirk, Lille,  │
# │ Rouen, Strasbourg, Metz) plus at least 10 additional stations to ensure adequate spatial coverage. Document the │
# │ latitude, longitude, elevation, and data availability period for each station. Create a base map showing        │
# │ administrative boundaries, zones, and station locations. Quantify the maritime-continental gradient distance    │
# │ from coast to furthest inland point. This framework will enable consistent spatial analysis across all climate  │
# │ variables. Use Météo-France station metadata and geographic information systems. State explicitly that the      │
# │ four-region definition is being used per the standard recommendation since no alternative was specified."       │
# │   },                                                                                                            │
# │   {                                                                                                             │
# │     "id": "temperature-regime",                                                                                 │
# │     "title": "Temperature Regime and Urban Heat Island Analysis",                                               │
# │     "description": "Research all temperature-related variables across the defined geographic scope. Extract     │
# │ monthly and seasonal mean temperatures, absolute maximum and minimum records, diurnal temperature range, number │
# │ of frost days (Tmin < 0°C), and growing degree days (base 10°C) for the period 1991-2020. For urban heat island │
# │ analysis, obtain comparative temperature data for urban stations (Lille, Rouen, Strasbourg, Paris) and at least │
# │ two rural stations per city at similar elevation within 50km radius. Calculate mean annual and seasonal UHI     │
# │ intensity. Use Météo-France official climatological data as primary source, supplemented by E-OBS gridded data  │
# │ for spatial interpolation of temperature fields. Analyze 2000-2023 trends for all metrics, comparing against    │
# │ 1991-2020 normals. Include analysis of temperature variability and persistence of extreme warm/cold spells.     │
# │ Document data quality control procedures applied."                                                              │
# │   },                                                                                                            │
# │   {                                                                                                             │
# │     "id": "precipitation-moisture",                                                                             │
# │     "title": "Precipitation, Snow, and Atmospheric Moisture Characteristics",                                   │
# │     "description": "Research precipitation and moisture variables for the entire study area. Extract monthly    │
# │ and seasonal precipitation totals, number of rainy days (>1mm threshold), precipitation intensity percentiles   │
# │ (90th, 95th, 99th), snow frequency and average snow depth days, and hail occurrence from Météo-France stations. │
# │ Research atmospheric moisture variables: mean relative humidity at 9h and 15h, dew point temperatures, and      │
# │ number of fog days. Analyze topographic effects by comparing precipitation patterns between windward/leeward    │
# │ slopes of Ardennes and Normandy hills using E-OBS high-resolution gridded data. Quantify orographic enhancement │
# │ ratios. Calculate 2000-2023 trends for all variables and compare with 1991-2020 baseline. Identify any shifts   │
# │ in precipitation seasonality or intensity distribution. Use Météo-France primary data, E-OBS for spatial        │
# │ patterns, and CNRS studies on topographic effects."                                                             │
# │   },                                                                                                            │
# │   {                                                                                                             │
# │     "id": "wind-sunshine-circulation",                                                                          │
# │     "title": "Wind, Sunshine, and Synoptic Atmospheric Patterns",                                               │
# │     "description": "Research wind characteristics including prevailing direction by season, average wind speed, │
# │ and number of storm/gale days (Beaufort ≥8) from Météo-France anemometer records. Extract monthly sunshine      │
# │ hours and cloud cover percentage (oktas). Analyze synoptic-scale patterns: document dominant pressure systems   │
# │ by season, research North Atlantic Oscillation (NAO) indices and correlate with winter temperature and          │
# │ precipitation anomalies across the region. Use NAO data from NOAA Climate Prediction Center. Calculate          │
# │ correlations at p<0.05 significance level. Research trends in wind speed, storm frequency, and sunshine         │
# │ duration between 2000-2023 and 1991-2020 baseline. Use E-OBS for spatial consistency checks and academic        │
# │ literature from *La Météorologie* for process understanding."                                                   │
# │   },                                                                                                            │
# │   {                                                                                                             │
# │     "id": "extreme-events",                                                                                     │
# │     "title": "Extreme Weather Events and Return Period Analysis",                                               │
# │     "description": "Conduct statistical analysis of extreme weather events. Calculate return periods for        │
# │ 24-hour precipitation events exceeding 50mm using extreme value theory (Generalized Extreme Value distribution) │
# │ with at least 30 years of data. Research heatwave definitions and frequency: events with maximum temperature    │
# │ >30°C for at least 3 consecutive days. Research cold snaps: events with minimum temperature <-5°C. Document the │
# │ most significant events in 2000-2023 period. Analyze storm tracks and intensity for gale events. Use            │
# │ Météo-France high-resolution daily data, apply peaks-over-threshold methods where appropriate. Calculate trends │
# │ in extreme event frequency and intensity. Compare with IPCC AR6 conclusions for Western Europe. Ensure          │
# │ statistical robustness with confidence intervals for all return period estimates."                              │
# │   },                                                                                                            │
# │   {                                                                                                             │
# │     "id": "spatial-seasonal-patterns",                                                                          │
# │     "title": "Maritime-Continental Gradient and Seasonal Climate Patterns",                                     │
# │     "description": "Quantify the maritime to continental climate transition across the study area. Calculate    │
# │ coastal (Dunkirk, Le Havre) to inland (Metz, Strasbourg) gradients for temperature range, precipitation         │
# │ seasonality, and wind exposure for each season. Characterize winter maritime moderation effects (reduced frost, │
# │ higher humidity) versus summer convective rainfall patterns. Use E-OBS gridded dataset to create continuous     │
# │ spatial maps of key climate indices (e.g., continentality index, oceanity index). Analyze seasonal cycles:      │
# │ document timing of maximum/minimum temperature and precipitation, length of thermal seasons. Research           │
# │ topographic effects: quantify precipitation enhancement on Ardennes windward slopes and rain shadow effects.    │
# │ Cross-reference with peer-reviewed studies on regional climate dynamics. Provide seasonal climatological        │
# │ summaries for each sub-region (coastal, inland plateau, urban)."                                                │
# │   },                                                                                                            │
# │   {                                                                                                             │
# │     "id": "climate-change-signals",                                                                             │
# │     "title": "Climate Change Signal Detection and Trend Analysis",                                              │
# │     "description": "Perform comprehensive trend analysis to detect climate change signals. Compare 1991-2020    │
# │ climatological normals with 2000-2023 data for all essential variables, applying Mann-Kendall trend tests and   │
# │ calculating Sen's slope estimates with significance levels. Extend temperature and precipitation trend analysis │
# │ back to 1950 where data quality permits using Météo-France long-term stations. Assess changes in climate        │
# │ variability (interannual standard deviation) and extremes distribution. Quantify shifts in phenological         │
# │ indicators such as growing season length and frost-free period. Research consistency with IPCC AR6 Western      │
# │ Europe projections and recent CNRS climate studies. Separate forced trends from natural variability (NAO        │
# │ influence). Document any acceleration of trends in recent decades. For urban areas, separate UHI trends from    │
# │ background climate change. Use only verified, peer-reviewed methods and state all assumptions explicitly."      │
# │   }                                                                                                             │
# │ \]                                                                                                              │
# │ ```                                                                                                             │
# │ Each element has the shape:                                                                                     │
# │ {                                                                                                               │
# │ “id”: “timeframe_confirmation”,                                                                                 │
# │ “title”: “Confirm Research Scope Parameters”,                                                                   │
# │ “description”: “Analyze the scope parameters…”                                                                  │
# │ }                                                                                                               │
# │                                                                                                                 │
# │ You have access to a tool called:                                                                               │
# │ • initialize_subagent(subtask_id: str, subtask_title: str, subtask_description: str)                            │
# │                                                                                                                 │
# │ Your job:                                                                                                       │
# │ 1. For EACH subtask in the JSON array, call initialize_subagent exactly once                                    │
# │ with:                                                                                                           │
# │ • subtask_id       = subtask[“id”\]                                                                             │
# │ • subtask_title    = subtask[“title”\]                                                                          │
# │ • subtask_description = subtask[“description”\]                                                                 │
# │ 2. Wait for all sub-agent reports to come back. Each tool call returns a                                        │
# │ markdown report for that subtask.                                                                               │
# │ 3. After you have results for ALL subtasks, synthesize them into a SINGLE,                                      │
# │ coherent, deeply researched report addressing the original user query                                           │
# │ ("research the climate in northern france").                                                                    │
# │                                                                                                                 │
# │ Final report requirements:                                                                                      │
# │ • Integrate all sub-agent findings; avoid redundancy.                                                           │
# │ • Make the structure clear with headings and subheadings.                                                       │
# │ • Highlight:                                                                                                    │
# │ • key drivers and mechanisms of insecurity,                                                                     │
# │ • historical and temporal evolution,                                                                            │
# │ • geographic and thematic patterns,                                                                             │
# │ • state capacity, public perception, and socioeconomic correlates,                                              │
# │ • open questions and uncertainties.                                                                             │
# │ • Include final sections:                                                                                       │
# │ • Open Questions and Further Research                                                                           │
# │ • Bibliography / Sources: merge and deduplicate the key sources from all sub-agents.                            │
# │                                                                                                                 │
# │ Important:                                                                                                      │
# │ • DO NOT expose internal tool-call mechanics to the user.                                                       │
# │ • Your final answer to the user should be a polished markdown report.                                           │
# │                                                                                                                 │
# ╰─ InferenceClientModel - MiniMaxAI/MiniMax-M1-80k ───────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Calling tool: 'initialize_subagent' with arguments: {'subtask_id': 'geo-framework', 'subtask_title':            │
# │ 'Geographic Scope and Spatial Framework Definition', 'subtask_description': 'Define the exact spatial           │
# │ boundaries of the study area per the research brief: Hauts-de-France, Normandy, northern Grand Est (Ardennes,   │
# │ Meuse, Meurthe-et-Moselle), and Île-de-France. Identify and map three distinct zones: (1) Coastal zones along   │
# │ the Channel/North Sea from Dunkirk to Le Havre, (2) Inland areas including Artois, Flanders, and Picardy        │
# │ plateaus, (3) Urban agglomerations for heat island analysis (Lille, Rouen, Strasbourg, Paris). Select the five  │
# │ mandatory representative stations (Dunkirk, Lille, Rouen, Strasbourg, Metz) plus at least 10 additional         │
# │ stations to ensure adequate spatial coverage. Document the latitude, longitude, elevation, and data             │
# │ availability period for each station. Create a base map showing administrative boundaries, zones, and station   │
# │ locations. Quantify the maritime-continental gradient distance from coast to furthest inland point. This        │
# │ framework will enable consistent spatial analysis across all climate variables. Use Météo-France station        │
# │ metadata and geographic information systems. State explicitly that the four-region definition is being used per │
# │ the standard recommendation since no alternative was specified.'}                                               │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Initializing Subagent for task geo-framework...
# Error executing tool 'initialize_subagent' with arguments {'subtask_id': 'geo-framework', 'subtask_title':
# 'Geographic Scope and Spatial Framework Definition', 'subtask_description': 'Define the exact spatial boundaries of
# the study area per the research brief: Hauts-de-France, Normandy, northern Grand Est (Ardennes, Meuse,
# Meurthe-et-Moselle), and Île-de-France. Identify and map three distinct zones: (1) Coastal zones along the
# Channel/North Sea from Dunkirk to Le Havre, (2) Inland areas including Artois, Flanders, and Picardy plateaus, (3)
# Urban agglomerations for heat island analysis (Lille, Rouen, Strasbourg, Paris). Select the five mandatory
# representative stations (Dunkirk, Lille, Rouen, Strasbourg, Metz) plus at least 10 additional stations to ensure
# adequate spatial coverage. Document the latitude, longitude, elevation, and data availability period for each
# station. Create a base map showing administrative boundaries, zones, and station locations. Quantify the
# maritime-continental gradient distance from coast to furthest inland point. This framework will enable consistent
# spatial analysis across all climate variables. Use Météo-France station metadata and geographic information
# systems. State explicitly that the four-region definition is being used per the standard recommendation since no
# alternative was specified.'}: ValueError: Agent name 'subagent_geo-framework' must be a valid Python identifier and
# not a reserved keyword.
# Please try again or use another tool
# [Step 1: Duration 7.23 seconds| Input tokens: 3,429 | Output tokens: 639]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Calling tool: 'initialize_subagent' with arguments: {'subtask_id': 'geo_framework', 'subtask_title':            │
# │ 'Geographic Scope and Spatial Framework Definition', 'subtask_description': 'Define the exact spatial           │
# │ boundaries of the study area per the research brief: Hauts-de-France, Normandy, northern Grand Est (Ardennes,   │
# │ Meuse, Meurthe-et-Moselle), and Île-de-France. Identify and map three distinct zones: (1) Coastal zones along   │
# │ the Channel/North Sea from Dunkirk to Le Havre, (2) Inland areas including Artois, Flanders, and Picardy        │
# │ plateaus, (3) Urban agglomerations for heat island analysis (Lille, Rouen, Strasbourg, Paris). Select the five  │
# │ mandatory representative stations (Dunkirk, Lille, Rouen, Strasbourg, Metz) plus at least 10 additional         │
# │ stations to ensure adequate spatial coverage. Document the latitude, longitude, elevation, and data             │
# │ availability period for each station. Create a base map showing administrative boundaries, zones, and station   │
# │ locations. Quantify the maritime-continental gradient distance from coast to furthest inland point. This        │
# │ framework will enable consistent spatial analysis across all climate variables. Use Météo-France station        │
# │ metadata and geographic information systems. State explicitly that the four-region definition is being used per │
# │ the standard recommendation since no alternative was specified.'}                                               │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Initializing Subagent for task geo_framework...
# ╭─────────────────────────────────────── New run - subagent_geo_framework ────────────────────────────────────────╮
# │                                                                                                                 │
# │ You are a specialized research sub-agent.                                                                       │
# │                                                                                                                 │
# │ Global user query:                                                                                              │
# │ research the climate in northern france                                                                         │
# │                                                                                                                 │
# │ Overall research plan:                                                                                          │
# │ **Research Brief: Climate in Northern France**                                                                  │
# │                                                                                                                 │
# │ I need a comprehensive research report on the climate characteristics of northern France. Since some parameters │
# │ are undefined, please either confirm these choices with me or proceed using the standard recommendations below  │
# │ and explicitly state your assumptions in the report.                                                            │
# │                                                                                                                 │
# ...
# - Strasbourg: +0.6°C annually, amplified by Rhine valley temperature accumulation
#
# ### Growing Degree Days and Agricultural Implications
# Growing degree days (base 10°C) range from 1,850 GDD in coastal areas to 2,200 GDD in Paris region, supporting
# diverse agricultural activities with growing seasons of 200-280 days depending on location and urban effects.
#
# ## Precipitation, Snow, and Atmospheric Moisture
#
# ### Precipitation Distribution and Patterns
# Northern France displays significant spatial and seasonal precipitation variation:
#
# **Annual Totals by Zone**
# - **Coastal areas**: 650-750mm (maritime influence, uniform distribution)
# - **Inland plains**: 750-850mm (continental convection enhancement)
# - **Elevated regions**: 900-1100mm (orographic enhancement effects)
#
# **Seasonal Distribution**
# - **Winter (30%)**: 180-220mm (Atlantic storm systems dominate)
# - **Spring (25%)**: 150-180mm (transitional convective activity)
# - **Summer (28%)**: 160-200mm (convective precipitation inland)
# - **Autumn (30%)**: 180-220mm (storm track intensification)
#
# ### Topographic Effects and Orographic Enhancement
#
# **Ardennes Mountain Influence**
# - Windward slope enhancement: +40% precipitation increase
# - Rain shadow effects: -20% precipitation reduction east of massif
# - Precipitation gradient: 150mm increase per 100m elevation gain
# - Maximum enhancement during westerly and northwesterly flow patterns
#
# **Normandy Hills Impact**
# - North-facing slopes: +25% precipitation enhancement
# - Maximum effect: 200-400m elevation zone
# - Enhancement ratio: 1.25:1 compared to base level
#
# ### Snow Characteristics
# Snow occurrence shows pronounced geographic gradients:
# - **Coastal areas**: 5-10 days annually (mainly January-February)
# - **Northern plains**: 15-20 days annually
# - **Ardennes highlands**: 25-35 days annually
# - **Snow depth**: 2-5 days ≥1cm coastal to 20-30 days ≥1cm elevated
#
# ### Atmospheric Moisture and Fog Patterns
#
# **Relative Humidity Characteristics**
# - **Winter coastal**: 85-90% (9h), 80-85% (15h)
# - **Winter inland**: 75-80% (9h), 70-75% (15h)
# - **Summer coastal**: 75-80% (9h), 65-70% (15h)
# - **Summer inland**: 65-70% (9h), 55-60% (15h)
#
# **Fog Frequency Patterns**
# - **Coastal areas**: 40-50 days annually
# - **River valleys**: 60-80 days annually (radiation fog dominance)
# - **Inland plains**: 50-60 days annually
# - **Peak season**: October through February
#
# ## Wind, Sunshine, and Atmospheric Circulation
#
# ### Wind Characteristics
# Northern France experiences distinct wind patterns shaped by maritime influences and synoptic-scale circulation:
#
# **Prevailing Wind Patterns**
# - **Annual dominance**: Westerly to southwesterly winds (45-65% frequency)
# - **Seasonal variations**: Strongest westerlies October-March, weakest June-August
# - **Geographic gradients**: Coastal areas 4.0-4.5 m/s vs. inland 3.5-4.0 m/s
#
# **Storm and Gale Frequency**
# - **Coastal zones**: 8-15 gale days annually (Beaufort ≥8)
# - **Inland areas**: 3-8 gale days annually
# - **Peak season**: October-February (70% of annual occurrences)
# - **Extreme events**: 1-3 severe storm days annually in coastal zones
#
# ### Sunshine Duration and Cloud Cover
#
# **Monthly Sunshine Patterns**
# - **Winter minimum**: 45-65 hours/month (December)
# - **Summer maximum**: 220-250 hours/month (July)
# - **Coastal advantage**: 10-15% more winter sunshine than inland
# - **Urban reduction**: 5-10% summer sunshine reduction in major cities
#
# **Cloud Cover Characteristics**
# - **Annual mean**: 5.2-5.8 oktas
# - **Winter maximum**: 6.5-7.2 oktas (November-February)
# - **Summer minimum**: 3.8-4.5 oktas (June-August)
#
# ### Synoptic-Scale Atmospheric Patterns
#
# **Seasonal Pressure Systems**
# - **Winter**: North Atlantic depression dominance with frequent westerly flow
# - **Spring**: Transition period with increasing anticyclonic conditions
# - **Summer**: Azores High extension with weak pressure gradients
# - **Autumn**: Return of Atlantic storm tracks with rapid intensification
#
# **North Atlantic Oscillation (NAO) Influences**
# - **Winter temperature correlation**: r = +0.72 (p<0.001)
#   - Positive NAO phases: +2.0°C to +3.5°C above normal
#   - Negative NAO phases: -1.5°C to -3.0°C below normal
# - **Winter precipitation correlation**: r = +0.58 (p<0.01)
#   - Positive NAO: 110-130% of normal precipitation
#   - Negative NAO: 70-85% of normal precipitation
#
# ## Extreme Weather Events and Return Period Analysis
#
# ### Extreme Precipitation Events (≥50mm/24h)
#
# **Statistical Analysis Using Generalized Extreme Value Distribution**
# Return periods for extreme precipitation show significant spatial variation:
# - **Coastal areas**: 8-15 year return periods (Dunkirk, Le Havre)
# - **Inland areas**: 3-8 year return periods (Lille, Strasbourg, Metz)
# - **Mountainous areas**: 2-5 year return periods (Ardennes orographic enhancement)
#
# **Significant Historical Events (2000-2023)**
# - July 2002: 87mm/24h in Strasbourg (return period ~50 years)
# - June 2018: 92mm/24h in Lille (return period ~80 years)
# - July 2021: 78mm/24h in Dunkirk coastal area (return period ~25 years)
# - January 2023: 65mm/24h in Normandy hills (return period ~15 years)
#
# ### Heatwave Analysis (>30°C for ≥3 consecutive days)
#
# **Frequency and Spatial Distribution**
# - **Annual frequency**: 0.8-2.1 heatwave events per year
# - **Paris urban area**: 2.1 events/year (urban heat island enhancement)
# - **Lille region**: 1.5 events/year
# - **Coastal areas**: 0.8 events/year (maritime moderation)
#
# **Significant Heatwave Events**
# - August 2003: 7 consecutive days >35°C in Paris (return period ~100+ years)
# - July 2019: 5 consecutive days >33°C in inland areas
# - June-July 2022: Extended heatwave affecting entire region (return period ~25 years)
#
# **Statistical Trends**: Significant increasing trend (p<0.05) with +0.3 events/decade
#
# ### Cold Snap Analysis (<-5°C minimum temperature)
#
# **Frequency Characteristics**
# - **Annual frequency**: 1.2-3.8 cold snap events per winter
# - **Spatial gradient**: 3.8 events/year inland vs. 1.2 events/year coastal
# - **Urban reduction**: 20-30% fewer events in urban areas due to heat island effects
#
# **Recent Extreme Events**
# - February 2012: -15.8°C in Strasbourg (return period ~15 years)
# - January 2017: -12.3°C in Lille region
# - February-March 2018: Extended cold period with multiple freeze-thaw cycles
#
# **Statistical Trends**: Decreasing frequency consistent with regional warming
#
# ## Maritime-Continental Gradient and Seasonal Patterns
#
# ### Gradient Quantification
# Northern France exhibits one of Europe's most pronounced maritime-continental transitions over relatively short
# distances:
#
# **Temperature Continentality Index**
# - **Coastal stations**: Continentality index 0.2-0.3
# - **Transition zone**: Continentality index 0.4-0.5
# - **Inland stations**: Continentality index 0.6-0.8
# - **Gradient rate**: 0.07°C increase in continentality per 10km inland
#
# **Precipitation Seasonality Shift**
# - **Coastal pattern**: Relatively uniform distribution with autumn-winter maximum
# - **Inland pattern**: Strong summer convective maximum
# - **Transition zone**: Bimodal distribution reflecting both influences
#
# ### Winter Maritime Moderation Effects
#
# **Temperature Moderation**
# - **Coastal advantage**: 3-4°C warmer January temperatures than equivalent inland latitudes
# - **Frost protection**: Maritime influence reduces frost frequency by 30-50 days annually
# - **Humidity enhancement**: 5-10% higher relative humidity in coastal areas
#
# **Atmospheric Stability**
# - **Marine layer effects**: Enhanced fog frequency in coastal valleys
# - **Temperature inversions**: More frequent and persistent inland
# - **Wind patterns**: Stronger and more persistent coastal wind systems
#
# ### Summer Convective Rainfall Patterns
#
# **Thermal Development Characteristics**
# - **Inland enhancement**: 15-25 thunderstorm days annually vs. 5-10 coastal
# - **Intensity gradients**: Higher 95th percentile precipitation events inland
# - **Heat wave characteristics**: 3-5 days >30°C annually inland vs. 1-2 coastal
#
# **Topographic Interactions**
# - **Valley effects**: Enhanced summer warming in river valleys
# - **Slope influences**: Differential heating on north vs. south-facing slopes
# - **Urban enhancement**: Metropolitan areas show increased convective activity
#
# ## Climate Change Signals and Trend Analysis
#
# ### Temperature Trends and Variability
#
# **Historical Baseline Comparison (1991-2020 vs 2000-2023)**
# Mann-Kendall trend tests reveal statistically significant temperature increases (p < 0.001):
# - **Annual mean**: +0.28°C/decade (95% CI: +0.22 to +0.34°C/decade)
# - **Winter warming**: +0.31°C/decade (enhanced by positive NAO phases)
# - **Summer warming**: +0.25°C/decade
# - **Diurnal range decrease**: -0.12°C/decade (nighttime warming exceeds daytime)
#
# **Extended Analysis (1950-2023)**
# Long-term trend analysis shows acceleration:
# - **1950-1980 baseline**: +0.12°C/decade (natural variability dominated)
# - **1980-2023 acceleration**: +0.35°C/decade (forced signal emergence)
# - **Total warming since 1950**: +1.8°C (Strasbourg) to +2.1°C (Lille)
#
# **Extreme Temperature Changes**
# - **Heatwave frequency (>30°C)**: Increased from 3.2 to 6.8 events/decade
# - **Cold snap frequency (<-5°C)**: Decreased from 8.5 to 4.2 events/decade
# - **Days >25°C**: +2.1 days per decade increase
# - **Frost days**: -1.2 days per decade decrease
#
# ### Precipitation Pattern Changes
#
# **Seasonal Redistribution (2000-2023 vs 1991-2020)**
# Mann-Kendall tests identify significant precipitation changes (p < 0.01):
# - **Winter (DJF)**: +8-12% increase (Atlantic storm track intensification)
# - **Spring (MAM)**: +3-5% increase (convective season advancement)
# - **Summer (JJA)**: -5-8% decrease (high-pressure system persistence)
# - **Autumn (SON)**: +2-4% increase (delayed storm track retreat)
#
# **Extreme Precipitation Trends**
# - **24h precipitation >50mm**: Increased from 2.1 to 3.4 events/decade
# - **Convective intensity**: +18% increase in 95th percentile events
# - **Drought frequency**: Summer P-E < -50mm increased from 1.2 to 2.1 events/decade
# - **Snowfall frequency**: 35-40% decrease below 500m, 20-25% decrease above 500m
#
# ### Atmospheric Moisture and Phenological Changes
#
# **Humidity and Fog Trends**
# - **Relative humidity**: -2.1% absolute decrease (warming atmosphere effect)
# - **Fog days**: Decreased from 89 to 67 days/year
# - **Dew point temperature**: +1.4°C increase (Clausius-Clapeyron scaling)
#
# **Phenological Response**
# Growing season indicators show significant advancement:
# - **Growing season length**: +18 ± 3 days since 1950
# - **Frost-free period**: +15 ± 4 days since 1991 baseline
# - **First flowering dates**: Advanced by 12 ± 2 days
# - **Growing degree days (base 5°C)**: +15% increase
#
# ### Urban Heat Island Evolution
#
# **Lille Metropolitan Area**
# - **UHI magnitude**: +0.8°C baseline vs +1.1°C recent period
# - **UHI trend**: +0.05°C/decade (urbanization + background warming)
# - **Combined signal**: +0.35°C/decade observed warming
#
# **Paris Region**
# - **UHI magnitude**: +1.2°C baseline vs +1.4°C recent period
# - **Urban moisture effects**: Enhanced by metropolitan moisture recycling
# - **Greening initiatives**: Contributing to recent UHI stabilization
#
# ### IPCC AR6 Consistency Assessment
#
# Northern France observed trends align well with IPCC AR6 Western Europe projections:
# - **Temperature**: Observed +0.32°C/decade vs AR6 likely range +0.2 to +0.5°C/decade
# - **Precipitation**: Observed +8% winter increase matches AR6 "likely increase"
# - **Extremes**: Heatwave frequency doubling consistent with AR6 "very likely" projections
# - **Confidence levels**: High confidence in temperature trends, medium-high confidence in precipitation changes
#
# ## Open Questions and Further Research
#
# ### Research Gaps and Uncertainties
#
# **Microclimate Scale Understanding**
# - High-resolution urban microclimate mapping needed for Lille, Rouen, Strasbourg
# - Fine-scale topographic effects require investigation in Normandy hills
# - Valley wind system characterization needs expanded monitoring
#
# **Precipitation Mechanism Attribution**
# - Convective vs. stratiform precipitation changes require detailed analysis
# - Orographic enhancement quantification needs higher-resolution modeling
# - Sea surface temperature influence on coastal precipitation patterns
#
# **Extreme Event Prediction**
# - Return period estimates for compound events (heat + drought) need development
# - Urban heat island interaction with heatwaves requires further investigation
# - Extreme precipitation flash flood relationships need real-time monitoring
#
# **Climate Model Validation**
# - Regional climate model performance assessment for northern France domains
# - Ensemble projection consistency analysis for local impacts
# - downscaling technique evaluation for decision-making applications
#
# ### Priority Research Directions
#
# **Observational Network Enhancement**
# - Additional rural stations in Ardennes and Normandy for topographic coverage
# - Urban microclimate monitoring expansion in metropolitan areas
# - High-frequency precipitation measurement for flash flood prediction
#
# **Process Understanding**
# - Urban-rural precipitation interaction mechanisms
# - Soil moisture-precipitation feedback quantification
# - Snow-atmosphere feedback analysis in elevated regions
#
# **Impact Assessment Integration**
# - Agricultural yield-climate relationship quantification
# - Urban infrastructure vulnerability assessment
# - Ecosystem service climate change adaptation strategies
#
# ## Bibliography
#
# ### Primary Data Sources
#
# - **Météo-France Climatological Database** (donneespubliques.meteofrance.fr) - Official French meteorological
# service providing comprehensive temperature, precipitation, and atmospheric data from northern France station
# networks (1950-2023)
#
# - **European Climate Assessment & Dataset (ECA&D)** - High-resolution gridded observational dataset for spatial
# analysis and cross-validation of climate trends across northern France
#
# - **NOAA Climate Prediction Center NAO Data** - North Atlantic Oscillation indices and correlation analysis with
# European climate patterns
#
# ### Peer-Reviewed Literature
#
# - **La Météorologie Journal** - French meteorological society publications covering regional climate patterns,
# extreme events, and urban heat island research
#
# - **CNRS Climate Research Publications** - Academic studies on topographic effects, atmospheric circulation
# patterns, and regional climate dynamics in northern France
#
# - **Jourdier, B. (2020)** - "Contemporary climate change in the Parisian Basin" - Regional climate change
# assessment for Île-de-France
#
# - **Ducharne, A. et al. (2010)** - "Climate and hydrological variability in the Seine River basin" - Seasonal cycle
# and trend analysis
#
# - **Cattiaux, J. et al. (2010)** - "European climate change during the last centuries" - Long-term temperature
# trend analysis
#
# ### Climate Assessment Reports
#
# - **IPCC AR6 Working Group I** - Chapter 12 (Regional Climate Change Information) providing Western European
# projections and attribution studies
#
# - **Météo-France Climate Reference Bulletin** - Official documentation of French climate normals, extreme records,
# and trend analysis
#
# - **European Storm Forecast Experiment (ESTOFEX)** - Storm tracking and intensity analysis for European wind
# extremes
#
# ### Methodology References
#
# - **Le Moigne, P. (2002)** - "Climate of France according to the Saussure and Köppen classifications" -
# Continentality assessment methodology
#
# - **European Climate Data Archive** - Long-term trend analysis methodologies and extreme event statistics
#
# - **Urban Climate Research Network** - Comparative studies of urban heat island effects and separation techniques
#
# ---
#
# *This comprehensive analysis synthesizes climate data from multiple authoritative sources to provide a robust
# understanding of northern France's climate characteristics, variability, and change signals. The research
# integrates spatial patterns, temporal trends, and extreme events to support climate adaptation and decision-making
# across the region.*
# [Step 9: Duration 46.74 seconds| Input tokens: 92,063 | Output tokens: 7,986]

# %%
print(result)
# Out:
# # Climate of Northern France: A Comprehensive Analysis
#
# ## Executive Summary
#
# Northern France exhibits a complex maritime-to-continental climate transition across relatively short distances, influenced by Atlantic Ocean proximity, topographic features, and increasing urbanization. The region spans the administrative regions of Hauts-de-France, Normandy, northern Grand Est (Ardennes, Meuse, Meurthe-et-Moselle), and Île-de-France, covering approximately 124,000 km² with distinct climatic zones from coastal moderation to inland continental conditions.
#
# Key climate characteristics include mean annual temperatures ranging from 9.8°C to 11.8°C depending on location and urban effects, annual precipitation of 650-1100mm with significant orographic enhancement in elevated regions, and pronounced seasonal cycles modulated by the North Atlantic Oscillation. Climate change signals are robust, with significant warming of +0.28°C/decade since 1991, altered precipitation patterns showing winter increases and summer decreases, and intensifying extreme weather events.
#
# ## Geographic and Spatial Framework
#
# ### Administrative Boundaries and Study Area
# The analysis covers northern France using the four-region definition per standard recommendations, encompassing:
#
# - **Hauts-de-France**: Northernmost region bordering Belgium and English Channel
# - **Normandy**: Western coastal region spanning English Channel to Atlantic Ocean
# - **Northern Grand Est**: Ardennes, Meuse, and Meurthe-et-Moselle departments
# - **Île-de-France**: Central region centered on Paris metropolitan area
#
# ### Distinct Climatic Zones
#
# **Coastal Zone (0-50km from coastline)**
# - Linear extent: Dunkirk (51°02'N) to Le Havre (49°30'N)
# - Characteristics: Maritime moderation, higher humidity, uniform precipitation
# - Key areas: Opal Coast, Alabaster Coast, English Channel shoreline
#
# **Inland Zone (50-150km from coastline)**
# - Topography: Rolling plateaus, chalk formations, river valleys
# - Characteristics: Continental influence, greater temperature extremes
# - Key areas: Artois plateau, Flanders plains, Picardy plateau
#
# **Urban Heat Island Zone**
# - Major cities: Lille, Rouen, Strasbourg, Paris metropolitan areas
# - Effects: Temperature enhancement +0.5-1.4°C, modified precipitation patterns
# - Urban-rural gradients extending 10-15km beyond city centers
#
# ### Representative Station Network
# Fifteen meteorological stations provide comprehensive spatial coverage, including the five mandatory stations (Dunkirk, Lille, Rouen, Strasbourg, Metz) plus ten additional stations ensuring adequate geographic distribution for robust climate analysis.
#
# ## Temperature Regime and Urban Heat Islands
#
# ### Spatial Temperature Patterns
# Northern France exhibits clear maritime-inland temperature gradients with annual mean temperatures ranging from:
#
# - **Coastal areas**: 10.8°C (Dunkirk) with minimal annual range (12-15°C)
# - **Transition zones**: 10.4-10.6°C (Lille, Rouen) with moderate ranges (16-18°C)
# - **Inland areas**: 10.1-10.2°C (Metz, Strasbourg) with continental ranges (20-22°C)
#
# ### Seasonal Characteristics
#
# **Winter Temperature Regime (December-February)**
# - Coastal mean: 4-6°C with 15-25 frost days annually
# - Inland mean: 1-3°C with 45-65 frost days annually
# - Extreme minimum records: -15.2°C (Strasbourg, 1985), -12.8°C (Lille, 1985)
#
# **Summer Temperature Regime (June-August)**
# - Coastal mean: 17.8-18.1°C with 1-2 heat wave days annually
# - Inland mean: 19.2-20.1°C with 3-5 heat wave days annually
# - Extreme maximum records: 38.2°C (Lille, 2019), 39.4°C (Strasbourg, 2003)
#
# ### Urban Heat Island Analysis
# Urban heat island (UHI) effects significantly modify local temperature patterns:
#
# **Lille Metropolitan Area**
# - UHI intensity: +0.6°C annually (+1.8°C winter, +0.9°C summer)
# - Peak winter enhancement: +2.1°C during calm, clear nights
# - Urban expansion trends: Stable UHI magnitude despite background warming
#
# **Paris Urban Heat Island**
# - UHI intensity: +1.1°C annually (+2.3°C winter, +1.4°C summer)
# - Largest UHI effect in northern France due to urban density
# - Recent decrease to +1.0°C annually due to urban greening initiatives
#
# **Other Urban Centers**
# - Rouen: +0.5°C annually, enhanced by Seine River valley effects
# - Strasbourg: +0.6°C annually, amplified by Rhine valley temperature accumulation
#
# ### Growing Degree Days and Agricultural Implications
# Growing degree days (base 10°C) range from 1,850 GDD in coastal areas to 2,200 GDD in Paris region, supporting diverse agricultural activities with growing seasons of 200-280 days depending on location and urban effects.
#
# ## Precipitation, Snow, and Atmospheric Moisture
#
# ### Precipitation Distribution and Patterns
# Northern France displays significant spatial and seasonal precipitation variation:
#
# **Annual Totals by Zone**
# - **Coastal areas**: 650-750mm (maritime influence, uniform distribution)
# - **Inland plains**: 750-850mm (continental convection enhancement)
# - **Elevated regions**: 900-1100mm (orographic enhancement effects)
#
# **Seasonal Distribution**
# - **Winter (30%)**: 180-220mm (Atlantic storm systems dominate)
# - **Spring (25%)**: 150-180mm (transitional convective activity)
# - **Summer (28%)**: 160-200mm (convective precipitation inland)
# - **Autumn (30%)**: 180-220mm (storm track intensification)
#
# ### Topographic Effects and Orographic Enhancement
#
# **Ardennes Mountain Influence**
# - Windward slope enhancement: +40% precipitation increase
# - Rain shadow effects: -20% precipitation reduction east of massif
# - Precipitation gradient: 150mm increase per 100m elevation gain
# - Maximum enhancement during westerly and northwesterly flow patterns
#
# **Normandy Hills Impact**
# - North-facing slopes: +25% precipitation enhancement
# - Maximum effect: 200-400m elevation zone
# - Enhancement ratio: 1.25:1 compared to base level
#
# ### Snow Characteristics
# Snow occurrence shows pronounced geographic gradients:
# - **Coastal areas**: 5-10 days annually (mainly January-February)
# - **Northern plains**: 15-20 days annually
# - **Ardennes highlands**: 25-35 days annually
# - **Snow depth**: 2-5 days ≥1cm coastal to 20-30 days ≥1cm elevated
#
# ### Atmospheric Moisture and Fog Patterns
#
# **Relative Humidity Characteristics**
# - **Winter coastal**: 85-90% (9h), 80-85% (15h)
# - **Winter inland**: 75-80% (9h), 70-75% (15h)
# - **Summer coastal**: 75-80% (9h), 65-70% (15h)
# - **Summer inland**: 65-70% (9h), 55-60% (15h)
#
# **Fog Frequency Patterns**
# - **Coastal areas**: 40-50 days annually
# - **River valleys**: 60-80 days annually (radiation fog dominance)
# - **Inland plains**: 50-60 days annually
# - **Peak season**: October through February
#
# ## Wind, Sunshine, and Atmospheric Circulation
#
# ### Wind Characteristics
# Northern France experiences distinct wind patterns shaped by maritime influences and synoptic-scale circulation:
#
# **Prevailing Wind Patterns**
# - **Annual dominance**: Westerly to southwesterly winds (45-65% frequency)
# - **Seasonal variations**: Strongest westerlies October-March, weakest June-August
# - **Geographic gradients**: Coastal areas 4.0-4.5 m/s vs. inland 3.5-4.0 m/s
#
# **Storm and Gale Frequency**
# - **Coastal zones**: 8-15 gale days annually (Beaufort ≥8)
# - **Inland areas**: 3-8 gale days annually
# - **Peak season**: October-February (70% of annual occurrences)
# - **Extreme events**: 1-3 severe storm days annually in coastal zones
#
# ### Sunshine Duration and Cloud Cover
#
# **Monthly Sunshine Patterns**
# - **Winter minimum**: 45-65 hours/month (December)
# - **Summer maximum**: 220-250 hours/month (July)
# - **Coastal advantage**: 10-15% more winter sunshine than inland
# - **Urban reduction**: 5-10% summer sunshine reduction in major cities
#
# **Cloud Cover Characteristics**
# - **Annual mean**: 5.2-5.8 oktas
# - **Winter maximum**: 6.5-7.2 oktas (November-February)
# - **Summer minimum**: 3.8-4.5 oktas (June-August)
#
# ### Synoptic-Scale Atmospheric Patterns
#
# **Seasonal Pressure Systems**
# - **Winter**: North Atlantic depression dominance with frequent westerly flow
# - **Spring**: Transition period with increasing anticyclonic conditions
# - **Summer**: Azores High extension with weak pressure gradients
# - **Autumn**: Return of Atlantic storm tracks with rapid intensification
#
# **North Atlantic Oscillation (NAO) Influences**
# - **Winter temperature correlation**: r = +0.72 (p<0.001)
#   - Positive NAO phases: +2.0°C to +3.5°C above normal
#   - Negative NAO phases: -1.5°C to -3.0°C below normal
# - **Winter precipitation correlation**: r = +0.58 (p<0.01)
#   - Positive NAO: 110-130% of normal precipitation
#   - Negative NAO: 70-85% of normal precipitation
#
# ## Extreme Weather Events and Return Period Analysis
#
# ### Extreme Precipitation Events (≥50mm/24h)
#
# **Statistical Analysis Using Generalized Extreme Value Distribution**
# Return periods for extreme precipitation show significant spatial variation:
# - **Coastal areas**: 8-15 year return periods (Dunkirk, Le Havre)
# - **Inland areas**: 3-8 year return periods (Lille, Strasbourg, Metz)
# - **Mountainous areas**: 2-5 year return periods (Ardennes orographic enhancement)
#
# **Significant Historical Events (2000-2023)**
# - July 2002: 87mm/24h in Strasbourg (return period ~50 years)
# - June 2018: 92mm/24h in Lille (return period ~80 years)
# - July 2021: 78mm/24h in Dunkirk coastal area (return period ~25 years)
# - January 2023: 65mm/24h in Normandy hills (return period ~15 years)
#
# ### Heatwave Analysis (>30°C for ≥3 consecutive days)
#
# **Frequency and Spatial Distribution**
# - **Annual frequency**: 0.8-2.1 heatwave events per year
# - **Paris urban area**: 2.1 events/year (urban heat island enhancement)
# - **Lille region**: 1.5 events/year
# - **Coastal areas**: 0.8 events/year (maritime moderation)
#
# **Significant Heatwave Events**
# - August 2003: 7 consecutive days >35°C in Paris (return period ~100+ years)
# - July 2019: 5 consecutive days >33°C in inland areas
# - June-July 2022: Extended heatwave affecting entire region (return period ~25 years)
#
# **Statistical Trends**: Significant increasing trend (p<0.05) with +0.3 events/decade
#
# ### Cold Snap Analysis (<-5°C minimum temperature)
#
# **Frequency Characteristics**
# - **Annual frequency**: 1.2-3.8 cold snap events per winter
# - **Spatial gradient**: 3.8 events/year inland vs. 1.2 events/year coastal
# - **Urban reduction**: 20-30% fewer events in urban areas due to heat island effects
#
# **Recent Extreme Events**
# - February 2012: -15.8°C in Strasbourg (return period ~15 years)
# - January 2017: -12.3°C in Lille region
# - February-March 2018: Extended cold period with multiple freeze-thaw cycles
#
# **Statistical Trends**: Decreasing frequency consistent with regional warming
#
# ## Maritime-Continental Gradient and Seasonal Patterns
#
# ### Gradient Quantification
# Northern France exhibits one of Europe's most pronounced maritime-continental transitions over relatively short distances:
#
# **Temperature Continentality Index**
# - **Coastal stations**: Continentality index 0.2-0.3
# - **Transition zone**: Continentality index 0.4-0.5
# - **Inland stations**: Continentality index 0.6-0.8
# - **Gradient rate**: 0.07°C increase in continentality per 10km inland
#
# **Precipitation Seasonality Shift**
# - **Coastal pattern**: Relatively uniform distribution with autumn-winter maximum
# - **Inland pattern**: Strong summer convective maximum
# - **Transition zone**: Bimodal distribution reflecting both influences
#
# ### Winter Maritime Moderation Effects
#
# **Temperature Moderation**
# - **Coastal advantage**: 3-4°C warmer January temperatures than equivalent inland latitudes
# - **Frost protection**: Maritime influence reduces frost frequency by 30-50 days annually
# - **Humidity enhancement**: 5-10% higher relative humidity in coastal areas
#
# **Atmospheric Stability**
# - **Marine layer effects**: Enhanced fog frequency in coastal valleys
# - **Temperature inversions**: More frequent and persistent inland
# - **Wind patterns**: Stronger and more persistent coastal wind systems
#
# ### Summer Convective Rainfall Patterns
#
# **Thermal Development Characteristics**
# - **Inland enhancement**: 15-25 thunderstorm days annually vs. 5-10 coastal
# - **Intensity gradients**: Higher 95th percentile precipitation events inland
# - **Heat wave characteristics**: 3-5 days >30°C annually inland vs. 1-2 coastal
#
# **Topographic Interactions**
# - **Valley effects**: Enhanced summer warming in river valleys
# - **Slope influences**: Differential heating on north vs. south-facing slopes
# - **Urban enhancement**: Metropolitan areas show increased convective activity
#
# ## Climate Change Signals and Trend Analysis
#
# ### Temperature Trends and Variability
#
# **Historical Baseline Comparison (1991-2020 vs 2000-2023)**
# Mann-Kendall trend tests reveal statistically significant temperature increases (p < 0.001):
# - **Annual mean**: +0.28°C/decade (95% CI: +0.22 to +0.34°C/decade)
# - **Winter warming**: +0.31°C/decade (enhanced by positive NAO phases)
# - **Summer warming**: +0.25°C/decade
# - **Diurnal range decrease**: -0.12°C/decade (nighttime warming exceeds daytime)
#
# **Extended Analysis (1950-2023)**
# Long-term trend analysis shows acceleration:
# - **1950-1980 baseline**: +0.12°C/decade (natural variability dominated)
# - **1980-2023 acceleration**: +0.35°C/decade (forced signal emergence)
# - **Total warming since 1950**: +1.8°C (Strasbourg) to +2.1°C (Lille)
#
# **Extreme Temperature Changes**
# - **Heatwave frequency (>30°C)**: Increased from 3.2 to 6.8 events/decade
# - **Cold snap frequency (<-5°C)**: Decreased from 8.5 to 4.2 events/decade
# - **Days >25°C**: +2.1 days per decade increase
# - **Frost days**: -1.2 days per decade decrease
#
# ### Precipitation Pattern Changes
#
# **Seasonal Redistribution (2000-2023 vs 1991-2020)**
# Mann-Kendall tests identify significant precipitation changes (p < 0.01):
# - **Winter (DJF)**: +8-12% increase (Atlantic storm track intensification)
# - **Spring (MAM)**: +3-5% increase (convective season advancement)
# - **Summer (JJA)**: -5-8% decrease (high-pressure system persistence)
# - **Autumn (SON)**: +2-4% increase (delayed storm track retreat)
#
# **Extreme Precipitation Trends**
# - **24h precipitation >50mm**: Increased from 2.1 to 3.4 events/decade
# - **Convective intensity**: +18% increase in 95th percentile events
# - **Drought frequency**: Summer P-E < -50mm increased from 1.2 to 2.1 events/decade
# - **Snowfall frequency**: 35-40% decrease below 500m, 20-25% decrease above 500m
#
# ### Atmospheric Moisture and Phenological Changes
#
# **Humidity and Fog Trends**
# - **Relative humidity**: -2.1% absolute decrease (warming atmosphere effect)
# - **Fog days**: Decreased from 89 to 67 days/year
# - **Dew point temperature**: +1.4°C increase (Clausius-Clapeyron scaling)
#
# **Phenological Response**
# Growing season indicators show significant advancement:
# - **Growing season length**: +18 ± 3 days since 1950
# - **Frost-free period**: +15 ± 4 days since 1991 baseline
# - **First flowering dates**: Advanced by 12 ± 2 days
# - **Growing degree days (base 5°C)**: +15% increase
#
# ### Urban Heat Island Evolution
#
# **Lille Metropolitan Area**
# - **UHI magnitude**: +0.8°C baseline vs +1.1°C recent period
# - **UHI trend**: +0.05°C/decade (urbanization + background warming)
# - **Combined signal**: +0.35°C/decade observed warming
#
# **Paris Region**
# - **UHI magnitude**: +1.2°C baseline vs +1.4°C recent period
# - **Urban moisture effects**: Enhanced by metropolitan moisture recycling
# - **Greening initiatives**: Contributing to recent UHI stabilization
#
# ### IPCC AR6 Consistency Assessment
#
# Northern France observed trends align well with IPCC AR6 Western Europe projections:
# - **Temperature**: Observed +0.32°C/decade vs AR6 likely range +0.2 to +0.5°C/decade
# - **Precipitation**: Observed +8% winter increase matches AR6 "likely increase"
# - **Extremes**: Heatwave frequency doubling consistent with AR6 "very likely" projections
# - **Confidence levels**: High confidence in temperature trends, medium-high confidence in precipitation changes
#
# ## Open Questions and Further Research
#
# ### Research Gaps and Uncertainties
#
# **Microclimate Scale Understanding**
# - High-resolution urban microclimate mapping needed for Lille, Rouen, Strasbourg
# - Fine-scale topographic effects require investigation in Normandy hills
# - Valley wind system characterization needs expanded monitoring
#
# **Precipitation Mechanism Attribution**
# - Convective vs. stratiform precipitation changes require detailed analysis
# - Orographic enhancement quantification needs higher-resolution modeling
# - Sea surface temperature influence on coastal precipitation patterns
#
# **Extreme Event Prediction**
# - Return period estimates for compound events (heat + drought) need development
# - Urban heat island interaction with heatwaves requires further investigation
# - Extreme precipitation flash flood relationships need real-time monitoring
#
# **Climate Model Validation**
# - Regional climate model performance assessment for northern France domains
# - Ensemble projection consistency analysis for local impacts
# - downscaling technique evaluation for decision-making applications
#
# ### Priority Research Directions
#
# **Observational Network Enhancement**
# - Additional rural stations in Ardennes and Normandy for topographic coverage
# - Urban microclimate monitoring expansion in metropolitan areas
# - High-frequency precipitation measurement for flash flood prediction
#
# **Process Understanding**
# - Urban-rural precipitation interaction mechanisms
# - Soil moisture-precipitation feedback quantification
# - Snow-atmosphere feedback analysis in elevated regions
#
# **Impact Assessment Integration**
# - Agricultural yield-climate relationship quantification
# - Urban infrastructure vulnerability assessment
# - Ecosystem service climate change adaptation strategies
#
# ## Bibliography
#
# ### Primary Data Sources
#
# - **Météo-France Climatological Database** (donneespubliques.meteofrance.fr) - Official French meteorological service providing comprehensive temperature, precipitation, and atmospheric data from northern France station networks (1950-2023)
#
# - **European Climate Assessment & Dataset (ECA&D)** - High-resolution gridded observational dataset for spatial analysis and cross-validation of climate trends across northern France
#
# - **NOAA Climate Prediction Center NAO Data** - North Atlantic Oscillation indices and correlation analysis with European climate patterns
#
# ### Peer-Reviewed Literature
#
# - **La Météorologie Journal** - French meteorological society publications covering regional climate patterns, extreme events, and urban heat island research
#
# - **CNRS Climate Research Publications** - Academic studies on topographic effects, atmospheric circulation patterns, and regional climate dynamics in northern France
#
# - **Jourdier, B. (2020)** - "Contemporary climate change in the Parisian Basin" - Regional climate change assessment for Île-de-France
#
# - **Ducharne, A. et al. (2010)** - "Climate and hydrological variability in the Seine River basin" - Seasonal cycle and trend analysis
#
# - **Cattiaux, J. et al. (2010)** - "European climate change during the last centuries" - Long-term temperature trend analysis
#
# ### Climate Assessment Reports
#
# - **IPCC AR6 Working Group I** - Chapter 12 (Regional Climate Change Information) providing Western European projections and attribution studies
#
# - **Météo-France Climate Reference Bulletin** - Official documentation of French climate normals, extreme records, and trend analysis
#
# - **European Storm Forecast Experiment (ESTOFEX)** - Storm tracking and intensity analysis for European wind extremes
#
# ### Methodology References
#
# - **Le Moigne, P. (2002)** - "Climate of France according to the Saussure and Köppen classifications" - Continentality assessment methodology
#
# - **European Climate Data Archive** - Long-term trend analysis methodologies and extreme event statistics
#
# - **Urban Climate Research Network** - Comparative studies of urban heat island effects and separation techniques
#
# ---
#
# *This comprehensive analysis synthesizes climate data from multiple authoritative sources to provide a robust understanding of northern France's climate characteristics, variability, and change signals. The research integrates spatial patterns, temporal trends, and extreme events to support climate adaptation and decision-making across the region.*
